# %%
# Seaborn is a library based on matplotlib and provides high level interface for drawing attractive and 
# informative statistical graphs
# Seaborn is a powerful visualization package build on matplotlib
# Seaborn makes visualizations better and provides more better functions, like an upgrade
import pandas as pd
stats = pd.read_csv('./DemographicData.csv')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
import matplotlib as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 12,4

# %% [markdown]
# import warnings
# warnings.filterwarnings('ignore')

# %%
filter1 = stats[stats['Internet users'] < 20]

# %%
filter1
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 1                 Afghanistan          AFG      35.253            5.90
# 2                      Angola          AGO      45.985           19.10
# 11                    Burundi          BDI      44.151            1.30
# 13                      Benin          BEN      36.440            4.90
# 14               Burkina Faso          BFA      40.551            9.10
# 15                 Bangladesh          BGD      20.142            6.63
# 28                   Botswana          BWA      25.267           15.00
# 29   Central African Republic          CAF      34.076            3.50
# 34              Cote d'Ivoire          CIV      37.320            8.40
# 35                   Cameroon          CMR      37.236            6.40
# 36                Congo, Rep.          COG      37.011            6.60
# 38                    Comoros          COM      34.326            6.50
# ...
